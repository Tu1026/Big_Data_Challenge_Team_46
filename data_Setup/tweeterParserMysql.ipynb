# %%
import tweepy
import time
import sqlite3
from contextlib import closing
import time
from tweepy import TweepError
import os
from dotenv import load_dotenv
from mysql.connector import connect, Error
load_dotenv()
# Out:
# True

# %%
consumer_key= os.getenv('consumer_key')
consumer_secret = os.getenv('consumer_secret')
access_token = os.getenv('access_token')
access_token_secret = os.getenv('access_token_secret')

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
id_lst =[]
single_call_count = 0
single_call_limit = 5
total_limit_count = 0
total_limit_requests = 899
count = 1

# %%
def packaging_data_for_update(hydrated_tweets):
    list_to_update = []
    good_set = set()
    for tweet in hydrated_tweets:
        try:
            text = tweet.retweeted_status.full_text
        except AttributeError:
            text = tweet.full_text
        Created_at = tweet.created_at
        location = tweet.user.location
        followers_count = int(tweet.user.followers_count)
        tweet_id = int(tweet.id)
        good_set.add(int(tweet_id))
        User_id = int(tweet.user.id)
        try:
            RT = tweet.retweeted_status.id
        except AttributeError:
            RT = 'False'
        try:
            retweet_count = tweet.retweeted_status.retweet_count
        except AttributeError:
            retweet_count = tweet.retweet_count
        list_to_update.append([Created_at, location, followers_count, RT, User_id, text, retweet_count, tweet_id])
    return list_to_update, good_set

# %%
db='BigData'
with closing(connect(host="localhost", user=os.getenv('USERNAME1'), password=os.getenv('PASSWORD1'), database=db)) as cnxn:
    with closing(cnxn.cursor()) as cursorIter:
        # cursorIter.execute('Select Tweet_ID from Sentiment where User_id is not null ')
        cursorIter.execute('Select Tweet_ID from Sentiment where Fetched is null')
        for row in cursorIter:
            if single_call_count >= single_call_limit:
                print(f'Fetching : {count} calls made')
                try:
                    hydrated_tweets = api.statuses_lookup(id_lst, tweet_mode = "extended")
                except TweepError:
                    time.sleep(60)
                    hydrated_tweets = api.statuses_lookup(id_lst, tweet_mode = "extended")
                packaged_info, good_set = packaging_data_for_update(hydrated_tweets)
                with closing(connect(host="localhost", user=os.getenv('USERNAME1'), password=os.getenv('PASSWORD1'), database=db)) as cnxn1:
                    with closing(cnxn1.cursor(buffered=True)) as cursorUpdater:
                        try:
                            cursorUpdater.executemany('update Sentiment set Created_at = %s, location = %s, followers_count = %s, Original_tweet = %s, User_id = %s, Content = %s, Retweet_count = %s, Fetched = "Yes" where Tweet_ID = %s', packaged_info)
                            cursorUpdater.executemany('update Sentiment set Fetched = "Yes" where Tweet_ID = %s', [[tweet] for tweet in set(id_lst) - good_set])
                        except:
                            pass
                        cnxn1.commit()
                single_call_count = 1
                id_lst = [row[0]]
                count += 1
            else:
                single_call_count += 1
                id_lst.append(row[0])
# Out:
# Rate limit reached. Sleeping for: 327
# Fetching : 1 calls made
# Fetching : 2 calls made
# Fetching : 3 calls made
# Fetching : 4 calls made
# Fetching : 5 calls made
# Fetching : 6 calls made
# Fetching : 7 calls made
# Fetching : 8 calls made
# Fetching : 9 calls made
# Fetching : 10 calls made
# Fetching : 11 calls made
# Fetching : 12 calls made
# Fetching : 13 calls made
# Fetching : 14 calls made
# Fetching : 15 calls made
# Fetching : 16 calls made
# Fetching : 17 calls made
# Fetching : 18 calls made
# Fetching : 19 calls made
# Fetching : 20 calls made
# Fetching : 21 calls made
# Fetching : 22 calls made
# Fetching : 23 calls made
# Fetching : 24 calls made
# Fetching : 25 calls made
# Fetching : 26 calls made
# Fetching : 27 calls made
# Fetching : 28 calls made
# Fetching : 29 calls made
# Fetching : 30 calls made
# Fetching : 31 calls made
# Fetching : 32 calls made
# Fetching : 33 calls made
# Fetching : 34 calls made
# Fetching : 35 calls made
# Fetching : 36 calls made
# Fetching : 37 calls made
# Fetching : 38 calls made
# Fetching : 39 calls made
# Fetching : 40 calls made
# Fetching : 41 calls made
# Fetching : 42 calls made
# Fetching : 43 calls made
# Fetching : 44 calls made
# Fetching : 45 calls made
# Fetching : 46 calls made
# Fetching : 47 calls made
# Fetching : 48 calls made
# Fetching : 49 calls made
# Fetching : 50 calls made
# Fetching : 51 calls made
# Fetching : 52 calls made
# Fetching : 53 calls made
# Fetching : 54 calls made
# Fetching : 55 calls made
# Fetching : 56 calls made
# Fetching : 57 calls made
# Fetching : 58 calls made
# Fetching : 59 calls made
# Fetching : 60 calls made
# Fetching : 61 calls made
# Fetching : 62 calls made
# Fetching : 63 calls made
# Fetching : 64 calls made
# Fetching : 65 calls made
# Fetching : 66 calls made
# Fetching : 67 calls made
# Fetching : 68 calls made
# Fetching : 69 calls made
# Fetching : 70 calls made
# Fetching : 71 calls made
# Fetching : 72 calls made
# Fetching : 73 calls made
# Fetching : 74 calls made
# Fetching : 75 calls made
# Fetching : 76 calls made
# Fetching : 77 calls made
# Fetching : 78 calls made
# Fetching : 79 calls made
# Fetching : 80 calls made
# Fetching : 81 calls made
# Fetching : 82 calls made
# Fetching : 83 calls made
# Fetching : 84 calls made
# Fetching : 85 calls made
# Fetching : 86 calls made
# Fetching : 87 calls made
# Fetching : 88 calls made
# Fetching : 89 calls made
# Fetching : 90 calls made
# Fetching : 91 calls made
# Fetching : 92 calls made
# Fetching : 93 calls made
# Fetching : 94 calls made
# Fetching : 95 calls made
# Fetching : 96 calls made
# Fetching : 97 calls made
# Fetching : 98 calls made
# Fetching : 99 calls made
# Fetching : 100 calls made
# Fetching : 101 calls made
# Fetching : 102 calls made
# Fetching : 103 calls made
# Fetching : 104 calls made
# Fetching : 105 calls made
# Fetching : 106 calls made
# Fetching : 107 calls made
# Fetching : 108 calls made
# Fetching : 109 calls made
# Fetching : 110 calls made
# Fetching : 111 calls made
# Fetching : 112 calls made
# Fetching : 113 calls made
# Fetching : 114 calls made
# Fetching : 115 calls made
# Fetching : 116 calls made
# Fetching : 117 calls made
# Fetching : 118 calls made
# Fetching : 119 calls made
# Fetching : 120 calls made
# Fetching : 121 calls made
# Fetching : 122 calls made
# Fetching : 123 calls made
# Fetching : 124 calls made
# Fetching : 125 calls made
# Fetching : 126 calls made
# Fetching : 127 calls made
# Fetching : 128 calls made
# Fetching : 129 calls made
# Fetching : 130 calls made
# Fetching : 131 calls made
# Fetching : 132 calls made
# Fetching : 133 calls made
# Fetching : 134 calls made
# Fetching : 135 calls made
# Fetching : 136 calls made
# Fetching : 137 calls made
# Fetching : 138 calls made
# Fetching : 139 calls made
# Fetching : 140 calls made
# Fetching : 141 calls made
# Fetching : 142 calls made
# Fetching : 143 calls made
# Fetching : 144 calls made
# Fetching : 145 calls made
# Fetching : 146 calls made
# Fetching : 147 calls made
# Fetching : 148 calls made
# Fetching : 149 calls made
# Fetching : 150 calls made
# Fetching : 151 calls made
# Fetching : 152 calls made
# Fetching : 153 calls made
# Fetching : 154 calls made
# Fetching : 155 calls made
# Fetching : 156 calls made
# Fetching : 157 calls made
# Fetching : 158 calls made
# Fetching : 159 calls made
# Fetching : 160 calls made
# Fetching : 161 calls made
# Fetching : 162 calls made
# Fetching : 163 calls made
# Fetching : 164 calls made
# Fetching : 165 calls made
# Fetching : 166 calls made
# Fetching : 167 calls made
# Fetching : 168 calls made
# Fetching : 169 calls made
# Fetching : 170 calls made
# Fetching : 171 calls made
# Fetching : 172 calls made
# Fetching : 173 calls made
# Fetching : 174 calls made
# Fetching : 175 calls made
# Fetching : 176 calls made
# Fetching : 177 calls made
# Fetching : 178 calls made
# Fetching : 179 calls made
# Fetching : 180 calls made
# Fetching : 181 calls made
# Fetching : 182 calls made
# Fetching : 183 calls made
# Fetching : 184 calls made
# Fetching : 185 calls made
# Fetching : 186 calls made
# Fetching : 187 calls made
# Fetching : 188 calls made
# Fetching : 189 calls made
# Fetching : 190 calls made
# Fetching : 191 calls made
# Fetching : 192 calls made
# Fetching : 193 calls made
# Fetching : 194 calls made
# Fetching : 195 calls made
# Fetching : 196 calls made
# Fetching : 197 calls made
# Fetching : 198 calls made
# Fetching : 199 calls made
# Fetching : 200 calls made
# Fetching : 201 calls made
# Fetching : 202 calls made
# Fetching : 203 calls made
# Fetching : 204 calls made
# Fetching : 205 calls made
# Fetching : 206 calls made
# Fetching : 207 calls made
# Fetching : 208 calls made
# Fetching : 209 calls made
# Fetching : 210 calls made
# Fetching : 211 calls made
# Fetching : 212 calls made
# Fetching : 213 calls made
# Fetching : 214 calls made
# Fetching : 215 calls made
# Fetching : 216 calls made
# Fetching : 217 calls made
# Fetching : 218 calls made
# Fetching : 219 calls made
# Fetching : 220 calls made
# Fetching : 221 calls made
# Fetching : 222 calls made
# Fetching : 223 calls made
# Fetching : 224 calls made
# Fetching : 225 calls made
# Fetching : 226 calls made
# Fetching : 227 calls made
# Fetching : 228 calls made
# Fetching : 229 calls made
# Fetching : 230 calls made
# Fetching : 231 calls made
# Fetching : 232 calls made
# Fetching : 233 calls made
# Fetching : 234 calls made
# Fetching : 235 calls made
# Fetching : 236 calls made
# Fetching : 237 calls made
# Fetching : 238 calls made
# Fetching : 239 calls made
# Fetching : 240 calls made
# Fetching : 241 calls made
# Fetching : 242 calls made
# Fetching : 243 calls made
# Fetching : 244 calls made
# Fetching : 245 calls made
# Fetching : 246 calls made
# Fetching : 247 calls made
# Fetching : 248 calls made
# Fetching : 249 calls made
# Fetching : 250 calls made
# Fetching : 251 calls made
# Fetching : 252 calls made
# Fetching : 253 calls made
# Fetching : 254 calls made
# Fetching : 255 calls made
# Fetching : 256 calls made
# Fetching : 257 calls made
# Fetching : 258 calls made
# Fetching : 259 calls made
# Fetching : 260 calls made
# Fetching : 261 calls made
# Fetching : 262 calls made
# Fetching : 263 calls made
# Fetching : 264 calls made
# Fetching : 265 calls made
# Fetching : 266 calls made
# Fetching : 267 calls made
# Fetching : 268 calls made
# Fetching : 269 calls made
# Fetching : 270 calls made
# Fetching : 271 calls made
# Fetching : 272 calls made
# Fetching : 273 calls made
# Fetching : 274 calls made
# Fetching : 275 calls made
# Fetching : 276 calls made
# Fetching : 277 calls made
# Fetching : 278 calls made
# Fetching : 279 calls made
# Fetching : 280 calls made
# Fetching : 281 calls made
# Fetching : 282 calls made
# Fetching : 283 calls made
# Fetching : 284 calls made
# Fetching : 285 calls made
# Fetching : 286 calls made
# Fetching : 287 calls made
# Fetching : 288 calls made
# Fetching : 289 calls made
# Fetching : 290 calls made
# Fetching : 291 calls made
# Fetching : 292 calls made
# Fetching : 293 calls made
# Fetching : 294 calls made
# Fetching : 295 calls made
# Fetching : 296 calls made
# Fetching : 297 calls made
# Fetching : 298 calls made
# Fetching : 299 calls made
# Fetching : 300 calls made
# Fetching : 301 calls made
# Fetching : 302 calls made
# Fetching : 303 calls made
# Fetching : 304 calls made
# Fetching : 305 calls made
# Fetching : 306 calls made
# Fetching : 307 calls made
# Fetching : 308 calls made
# Fetching : 309 calls made
# Fetching : 310 calls made
# Fetching : 311 calls made
# Fetching : 312 calls made
# Fetching : 313 calls made
# Fetching : 314 calls made
# Fetching : 315 calls made
# Fetching : 316 calls made
# Fetching : 317 calls made
# Fetching : 318 calls made
# Fetching : 319 calls made
# Fetching : 320 calls made
# Fetching : 321 calls made
# Fetching : 322 calls made
# Fetching : 323 calls made
# Fetching : 324 calls made
# Fetching : 325 calls made
# Fetching : 326 calls made
# Fetching : 327 calls made
# Fetching : 328 calls made
# Fetching : 329 calls made
# Fetching : 330 calls made
# Fetching : 331 calls made
# Fetching : 332 calls made
# Fetching : 333 calls made
# Fetching : 334 calls made
# Fetching : 335 calls made
# Fetching : 336 calls made
# Fetching : 337 calls made
# Fetching : 338 calls made
# Fetching : 339 calls made
# Fetching : 340 calls made
# Fetching : 341 calls made
# Fetching : 342 calls made
# Fetching : 343 calls made
# Fetching : 344 calls made
# Fetching : 345 calls made
# Fetching : 346 calls made
# Fetching : 347 calls made
# Fetching : 348 calls made
# Fetching : 349 calls made
# Fetching : 350 calls made
# Fetching : 351 calls made
# Fetching : 352 calls made
# Fetching : 353 calls made
# Fetching : 354 calls made
# Fetching : 355 calls made
# Fetching : 356 calls made
# Fetching : 357 calls made
# Fetching : 358 calls made
# Fetching : 359 calls made
# Fetching : 360 calls made
# Fetching : 361 calls made
# Fetching : 362 calls made
# Fetching : 363 calls made
# Fetching : 364 calls made
# Fetching : 365 calls made
# Fetching : 366 calls made
# Fetching : 367 calls made
# Fetching : 368 calls made
# Fetching : 369 calls made
# Fetching : 370 calls made
# Fetching : 371 calls made
# Fetching : 372 calls made
# Fetching : 373 calls made
# Fetching : 374 calls made
# Fetching : 375 calls made
# Fetching : 376 calls made
# Fetching : 377 calls made
# Fetching : 378 calls made
# Fetching : 379 calls made
# Fetching : 380 calls made
# Fetching : 381 calls made
# Fetching : 382 calls made
# Fetching : 383 calls made
# Fetching : 384 calls made
# Fetching : 385 calls made
# Fetching : 386 calls made
# Fetching : 387 calls made
# Fetching : 388 calls made
# Fetching : 389 calls made
# Fetching : 390 calls made
# Fetching : 391 calls made
# Fetching : 392 calls made
# Fetching : 393 calls made
# Fetching : 394 calls made
# Fetching : 395 calls made
# Fetching : 396 calls made
# Fetching : 397 calls made
# Fetching : 398 calls made
# Fetching : 399 calls made
# Fetching : 400 calls made
# Fetching : 401 calls made
# Fetching : 402 calls made
# Fetching : 403 calls made
# Fetching : 404 calls made
# Fetching : 405 calls made
# Fetching : 406 calls made
# Fetching : 407 calls made
# Fetching : 408 calls made
# Fetching : 409 calls made
# Fetching : 410 calls made
# Fetching : 411 calls made
# Fetching : 412 calls made
# Fetching : 413 calls made
# Fetching : 414 calls made
# Fetching : 415 calls made
# Fetching : 416 calls made
# Fetching : 417 calls made
# Fetching : 418 calls made
# Fetching : 419 calls made
# Fetching : 420 calls made
# Fetching : 421 calls made
# Fetching : 422 calls made
# Fetching : 423 calls made
# Fetching : 424 calls made
# Fetching : 425 calls made
# Fetching : 426 calls made
# Fetching : 427 calls made
# Fetching : 428 calls made
# Fetching : 429 calls made
# Fetching : 430 calls made
# Fetching : 431 calls made
# Fetching : 432 calls made
# Fetching : 433 calls made
# Fetching : 434 calls made
# Fetching : 435 calls made
# Fetching : 436 calls made
# Fetching : 437 calls made
# Fetching : 438 calls made
# Fetching : 439 calls made
# Fetching : 440 calls made
# Fetching : 441 calls made
# Fetching : 442 calls made
# Fetching : 443 calls made
# Fetching : 444 calls made
# Fetching : 445 calls made
# Fetching : 446 calls made
# Fetching : 447 calls made
# Fetching : 448 calls made
# Rate limit reached. Sleeping for: 792
# Fetching : 449 calls made

# %%
lst1 = set([1, 2 ,3])
lst2 = set([2, 3, 4])
print([x for x in lst2])
# Out:
# [2, 3, 4]

# %%
example = api.statuses_lookup([1289350148263251969, 1289350148334657537], tweet_mode="extended")

# %%
# print(example[0].retweeted_status.full_text)
try:
    print(example[1].retweeted_status.id)
except AttributeError:
    print(example[0].retweet_count)
# followers_count = int(tweet._json['user']['followers_count'])
# User_id = int(tweet._json['user']['id'])
# RT = bool(re.match('^RT', tweet._json['text']))
# tweet_id = int(tweet._json['id'])
# text = tweet._json['text']
print(example[0].retweeted_status)
# Out:
# 1289309756415336448
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-214024fb9ce0> in <module>
#       9 # tweet_id = int(tweet._json['id'])
#      10 # text = tweet._json['text']
# ---> 11 print(example[0].retweeted_status)
#
# AttributeError: 'Status' object has no attribute 'retweeted_status'

# %%
import json
with open('test.txt', 'w') as f:
    json.dump(example[0]._json, f)
    json.dump(example[1]._json, f)

# %%
import json
import re
status = example[0]
print(status._json['created_at'])
print(status._json['user']['location'])
print(status._json['user']['followers_count'])
print(status._json['user']['id'])
print(re.match('^RT', status._json['text']))
print(status._json['id'])
# text
# created_at
# location
# followers_count
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-0fb47d5e2e77> in <module>
#       1 import json
#       2 import re
# ----> 3 status = example[0]
#       4 print(status._json['created_at'])
#       5 print(status._json['user']['location'])
#
# IndexError: list index out of range
